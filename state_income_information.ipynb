# %%
import pandas as pd
income = pd.read_csv('kaggle_income.csv', encoding='Latin-1')
# requires Latin-1 encoding to open the CSV

income.shape # 32,526 rows
income.head() # Get overview of dataset
# Out:
#         id  State_Code State_Name State_ab          County            City  \
# 0  1011000           1    Alabama       AL   Mobile County       Chickasaw
# 1  1011010           1    Alabama       AL  Barbour County      Louisville
# 2  1011020           1    Alabama       AL   Shelby County      Columbiana
# 3  1011030           1    Alabama       AL   Mobile County         Satsuma
# 4  1011040           1    Alabama       AL   Mobile County  Dauphin Island
#
#              Place  Type Primary  Zip_Code Area_Code     ALand     AWater  \
# 0   Chickasaw city  City   place     36611       251  10894952     909156
# 1        Clio city  City   place     36048       334  26070325      23254
# 2  Columbiana city  City   place     35051       205  44835274     261034
# 3      Creola city  City   place     36572       251  36878729    2374530
# 4   Dauphin Island  Town   place     36528       251  16204185  413605152
#
#          Lat        Lon   Mean  Median  Stdev        sum_w
# ...

# %%
income['State_Name'].value_counts() # Count per state
income.loc[income['State_Name'] == 'Florida']
# Out:
#             id  State_Code State_Name State_ab               County  \
# 5901  12011193          12    Florida       FL           Lee County
# 5902  12011203          12    Florida       FL          Clay County
# 5903  12011213          12    Florida       FL        Orange County
# 5904  12011223          12    Florida       FL        Orange County
# 5905  12011233          12    Florida       FL          Clay County
# 5906  12011243          12    Florida       FL       Flagler County
# 5907  12011253          12    Florida       FL    Palm Beach County
# 5908  12011263          12    Florida       FL  Hillsborough County
# 5909  12011273          12    Florida       FL    Santa Rosa County
# 5910  12011283          12    Florida       FL        Nassau County
# 5911  12011293          12    Florida       FL    Washington County
# 5912  12011303          12    Florida       FL       Gadsden County
# 5913  12011313          12    Florida       FL  Hillsborough County
# ...

# %%
income.describe()
# Out:
#                  id    State_Code      Zip_Code         ALand        AWater  \
# count  3.252600e+04  32526.000000  32526.000000  3.252600e+04  3.252600e+04
# mean   6.203707e+07     28.624885  50182.648404  1.165893e+08  6.952054e+06
# std    1.115546e+08     16.297205  29410.122808  1.280894e+09  2.092093e+08
# min    1.026000e+03      1.000000    601.000000  0.000000e+00  0.000000e+00
# 25%    8.021282e+06     13.000000  26362.000000  1.906991e+06  0.000000e+00
# 50%    2.901168e+07     29.000000  48163.000000  5.022976e+06  2.703350e+04
# 75%    4.802899e+07     42.000000  76712.000000  3.090984e+07  5.082078e+05
# max    4.802211e+08     72.000000  99950.000000  9.163267e+10  2.453228e+10
#
#                 Lat           Lon           Mean         Median  \
# count  32526.000000  32526.000000   32526.000000   32526.000000
# mean      37.731983    -91.303844   66703.986042   85452.938818
# std        5.579450     16.227588   30451.194599   87810.895132
# ...

# %%
FL = income[income['State_ab'] == "FL"]
FL.head()
# Out:
#             id  State_Code State_Name State_ab         County  \
# 5901  12011193          12    Florida       FL     Lee County
# 5902  12011203          12    Florida       FL    Clay County
# 5903  12011213          12    Florida       FL  Orange County
# 5904  12011223          12    Florida       FL  Orange County
# 5905  12011233          12    Florida       FL    Clay County
#
#                     City                        Place Type Primary  Zip_Code  \
# 5901                Alva                         Alva  CDP   place     33920
# 5902  Green Cove Springs                  Asbury Lake  CDP   place     32043
# 5903             Orlando                  Azalea Park  CDP   place     32807
# 5904             Orlando                     Bay Hill  CDP   place     32836
# 5905         Orange Park  Bellair-Meadowbrook Terrace  CDP   place     32073
#
#      Area_Code     ALand   AWater        Lat        Lon    Mean  Median  \
# ...

# %%
FL.loc[FL['Median'].idxmax]
FL.loc[FL['Median'].idxmax]
FL.nlargest(10,'Mean')
# Out:
#              id  State_Code State_Name State_ab               County  \
# 6038  120210380          12    Florida       FL       Alachua County
# 6054  120210520          12    Florida       FL       Alachua County
# 5936   12011543          12    Florida       FL    Miami-Dade County
# 5960   12011783          12    Florida       FL  Indian River County
# 6071  120210680          12    Florida       FL       Alachua County
# 6536  120214870          12    Florida       FL       Alachua County
# 7548   12029870          12    Florida       FL       Alachua County
# 6072  120210690          12    Florida       FL       Alachua County
# 6299  120212730          12    Florida       FL       Alachua County
# 6305  120212790          12    Florida       FL       Alachua County
#
#                     City             Place     Type Primary  Zip_Code  \
# 6038         Miami Beach  Gainesville city    Track   Track     33139
# ...

# %%
CA = income[income['State_ab'] == "CA"].nlargest(10,'Mean')
CA
# Out:
#             id  State_Code  State_Name State_ab          County  \
# 3341  60224419           6  California       CA  Alameda County
# 2910  60220539           6  California       CA  Alameda County
# 2157  60213769           6  California       CA  Alameda County
# 3677  60227449           6  California       CA  Alameda County
# 3814  60228689           6  California       CA  Alameda County
# 2147  60213679           6  California       CA  Alameda County
# 2547  60217279           6  California       CA  Alameda County
# 3451  60225409           6  California       CA  Alameda County
# 3811  60228659           6  California       CA  Alameda County
# 2919  60220619           6  California       CA  Alameda County
#
#                   City         Place   Type Primary  Zip_Code Area_Code  \
# 3341         San Diego  Alameda city  Track   Track     92110       619
# 2910  Huntington Beach  Alameda city  Track   Track     92648       714
# ...

# %%
NY = income[income['State_ab'] == "NY"].nlargest(10,'Mean')
NY
# Out:
#               id  State_Code State_Name State_ab         County  \
# 20054  360219824          36   New York       NY  Albany County
# 20058  360219854          36   New York       NY  Albany County
# 19271  360212774          36   New York       NY  Albany County
# 19136  360211554          36   New York       NY  Albany County
# 19139  360211584          36   New York       NY  Albany County
# 20174   36022554          36   New York       NY  Albany County
# 19928  360218684          36   New York       NY  Albany County
# 19227  360212384          36   New York       NY  Albany County
# 19192  360212064          36   New York       NY  Albany County
# 20068  360219944          36   New York       NY  Albany County
#
#                 City        Place   Type Primary  Zip_Code Area_Code  \
# 20054     Bronxville  Albany city  Track   Track     10708       914
# 20058         Pelham  Albany city  Track   Track     10803       914
# ...
