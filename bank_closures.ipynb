# %%
import pandas as pd
banks = pd.read_csv("banklist.csv")
banks.dtypes
# Out:
# Bank Name                object
# City                     object
# ST                       object
# CERT                      int64
# Acquiring Institution    object
# Closing Date             object
# Updated Date             object
# dtype: object

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

sns.countplot(x=pd.DatetimeIndex(banks["Closing Date"]).year, data=banks)
plt.locator_params(axis='x',nbins=5)

# %%
ax = sns.distplot(pd.DatetimeIndex(banks["Closing Date"]).year)

# %%
banks.head()
# Out:
#                                            Bank Name         City  ST   CERT  \
# 0                Washington Federal Bank for Savings      Chicago  IL  30570
# 1    The Farmers and Merchants State Bank of Argonia      Argonia  KS  17719
# 2                                Fayette County Bank   Saint Elmo  IL   1802
# 3  Guaranty Bank, (d/b/a BestBank in Georgia & Mi...    Milwaukee  WI  30003
# 4                                     First NBC Bank  New Orleans  LA  58302
#
#                  Acquiring Institution Closing Date Updated Date
# 0                   Royal Savings Bank    15-Dec-17     1-Feb-19
# 1                          Conway Bank    13-Oct-17    21-Feb-18
# 2            United Fidelity Bank, fsb    26-May-17    29-Jan-19
# 3  First-Citizens Bank & Trust Company     5-May-17    22-Mar-18
# 4                         Whitney Bank    28-Apr-17    29-Jan-19

# %%
banks.describe()
# Out:
#                CERT
# count    546.000000
# mean   31880.597070
# std    16413.244913
# min       91.000000
# 25%    20346.000000
# 50%    32232.500000
# 75%    35382.000000
# max    58701.000000

# %%
banks["ST"].nunique() # 42 unique 
banks.loc[banks["ST"]=="FL",].count()
banks["ST"].isin(["FL", "CA"]).value_counts()
banks.groupby(banks["ST"]).count().sort_values('City', ascending=False)
# Out:
#     Bank Name  City  CERT  Acquiring Institution  Closing Date  Updated Date
# ST
# GA         93    93    93                     93            93            93
# FL         74    74    74                     74            74            74
# IL         67    67    67                     67            67            67
# CA         41    41    41                     41            41            41
# MN         23    23    23                     23            23            23
# WA         19    19    19                     19            19            19
# AZ         16    16    16                     16            16            16
# MO         16    16    16                     16            16            16
# MI         14    14    14                     14            14            14
# NV         12    12    12                     12            12            12
# TX         11    11    11                     11            11            11
# ...

# %%
# functions to use
banks = banks.sort_values(by="City") # sort by values, alphabetical
banks.info() # counts of items
banks.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 546 entries, 259 to 131
# Data columns (total 7 columns):
# Bank Name                546 non-null object
# City                     546 non-null object
# ST                       546 non-null object
# CERT                     546 non-null int64
# Acquiring Institution    546 non-null object
# Closing Date             546 non-null object
# Updated Date             546 non-null object
# dtypes: int64(1), object(6)
# memory usage: 34.1+ KB
# Bank Name                546
# City                     546
# ST                       546
# CERT                     546
# Acquiring Institution    546
# Closing Date             546
# Updated Date             546
# dtype: int64

# %%
sns.countplot(x=banks["ST"], data=banks)
plt.locator_params(axis='x',nbins=10)
